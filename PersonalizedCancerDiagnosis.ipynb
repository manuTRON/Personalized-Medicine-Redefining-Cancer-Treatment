# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
# Out:
# C:\Users\MANAS\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training/training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training/training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 436.77852096314587 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.519611023703598
# Log loss on Test Data using Random Model 2.522476043803302
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 235
# BRCA1     164
# TP53      109
# PTEN       95
# EGFR       93
# BRCA2      78
# KIT        63
# BRAF       51
# ERBB2      46
# PDGFRA     42
# ALK        40
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 235 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer()
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 2119    CCND1
# 3125     KRAS
# 118     PBRM1
# 1415    FGFR3
# 2485    BRCA1
# Name: Gene, dtype: object

# %%
gene_vectorizer.get_feature_names()
# Out:
# ['abl1',
#  'acvr1',
#  'ago2',
#  'akt1',
#  'akt2',
#  'akt3',
#  'alk',
#  'apc',
#  'ar',
#  'araf',
#  'arid1b',
#  'arid2',
#  'arid5b',
#  'asxl1',
#  'asxl2',
#  'atm',
#  'atrx',
#  'aurka',
#  'aurkb',
#  'axin1',
#  'b2m',
#  'bap1',
#  'bcl10',
#  'bcl2',
#  'bcl2l11',
#  'bcor',
#  'braf',
#  'brca1',
#  'brca2',
#  'brip1',
#  'btk',
#  'card11',
#  'carm1',
#  'casp8',
#  'cbl',
#  'ccnd1',
#  'ccnd2',
#  'ccnd3',
#  'ccne1',
#  'cdh1',
#  'cdk12',
#  'cdk4',
#  'cdk6',
#  'cdk8',
#  'cdkn1a',
#  'cdkn1b',
#  'cdkn2a',
#  'cdkn2b',
#  'cdkn2c',
#  'cebpa',
#  'chek2',
#  'cic',
#  'crebbp',
#  'ctcf',
#  'ctla4',
#  'ctnnb1',
#  'ddr2',
#  'dicer1',
#  'dnmt3a',
#  'dnmt3b',
#  'dusp4',
#  'egfr',
#  'eif1ax',
#  'elf3',
#  'ep300',
#  'epas1',
#  'erbb2',
#  'erbb3',
#  'erbb4',
#  'ercc2',
#  'ercc3',
#  'ercc4',
#  'erg',
#  'esr1',
#  'etv1',
#  'etv6',
#  'ewsr1',
#  'ezh2',
#  'fam58a',
#  'fanca',
#  'fancc',
#  'fat1',
#  'fbxw7',
#  'fgf19',
#  'fgf3',
#  'fgf4',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'fgfr4',
#  'flt3',
#  'foxa1',
#  'foxl2',
#  'foxp1',
#  'fubp1',
#  'gli1',
#  'gna11',
#  'gnas',
#  'h3f3a',
#  'hist1h1c',
#  'hla',
#  'hnf1a',
#  'hras',
#  'idh1',
#  'idh2',
#  'igf1r',
#  'ikbke',
#  'ikzf1',
#  'il7r',
#  'inpp4b',
#  'jak1',
#  'jak2',
#  'jun',
#  'kdm5a',
#  'kdm5c',
#  'kdr',
#  'keap1',
#  'kit',
#  'kmt2a',
#  'kmt2c',
#  'knstrn',
#  'kras',
#  'lats2',
#  'map2k1',
#  'map2k2',
#  'map2k4',
#  'map3k1',
#  'mapk1',
#  'mdm2',
#  'mdm4',
#  'med12',
#  'mef2b',
#  'men1',
#  'met',
#  'mga',
#  'mlh1',
#  'mpl',
#  'msh2',
#  'msh6',
#  'mtor',
#  'myc',
#  'myd88',
#  'myod1',
#  'nf1',
#  'nf2',
#  'nfe2l2',
#  'nfkbia',
#  'nkx2',
#  'notch1',
#  'notch2',
#  'npm1',
#  'nras',
#  'nsd1',
#  'ntrk1',
#  'ntrk2',
#  'ntrk3',
#  'nup93',
#  'pak1',
#  'pax8',
#  'pbrm1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3cb',
#  'pik3cd',
#  'pik3r1',
#  'pik3r2',
#  'pik3r3',
#  'pim1',
#  'pms2',
#  'pole',
#  'ppm1d',
#  'ppp2r1a',
#  'ppp6c',
#  'prdm1',
#  'ptch1',
#  'pten',
#  'ptpn11',
#  'ptprd',
#  'ptprt',
#  'rab35',
#  'rac1',
#  'rad50',
#  'rad51c',
#  'rad51d',
#  'rad54l',
#  'raf1',
#  'rasa1',
#  'rb1',
#  'ret',
#  'rheb',
#  'rhoa',
#  'rictor',
#  'rit1',
#  'rnf43',
#  'ros1',
#  'runx1',
#  'rybp',
#  'sdhb',
#  'sdhc',
#  'setd2',
#  'sf3b1',
#  'shoc2',
#  'shq1',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smarca4',
#  'smarcb1',
#  'smo',
#  'sos1',
#  'sox9',
#  'spop',
#  'src',
#  'stag2',
#  'stat3',
#  'stk11',
#  'tcf3',
#  'tert',
#  'tet1',
#  'tet2',
#  'tgfbr1',
#  'tgfbr2',
#  'tmprss2',
#  'tp53',
#  'tp53bp1',
#  'tsc1',
#  'tsc2',
#  'u2af1',
#  'vegfa',
#  'vhl',
#  'whsc1',
#  'xpo1',
#  'yap1']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 234)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.2510778080803768
# For values of alpha =  0.0001 The log loss is: 1.2461557319567234
# For values of alpha =  0.001 The log loss is: 1.295844726688122
# For values of alpha =  0.01 The log loss is: 1.41673190244331
# For values of alpha =  0.1 The log loss is: 1.484740324954003
# For values of alpha =  1 The log loss is: 1.5042659536785827
# For values of best alpha =  0.0001 The train log loss is: 0.986627704588881
# For values of best alpha =  0.0001 The cross validation log loss is: 1.2461557319567234
# For values of best alpha =  0.0001 The test log loss is: 1.2032090431286795

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  235  genes in train dataset?
# Ans
# 1. In test data 638 out of 665 : 95.93984962406014
# 2. In cross validation data 519 out of  532 : 97.55639097744361

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1939
# Truncating_Mutations    56
# Amplification           45
# Deletion                44
# Fusions                 19
# Overexpression           4
# G12V                     3
# E17K                     3
# R841K                    2
# Q61R                     2
# K117N                    2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1939 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02636535 0.04755179 0.06826742 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer()
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1964)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7108676394084659
# For values of alpha =  0.0001 The log loss is: 1.7044302355130085
# For values of alpha =  0.001 The log loss is: 1.704183682582109
# For values of alpha =  0.01 The log loss is: 1.7116707609066435
# For values of alpha =  0.1 The log loss is: 1.7209680476133165
# For values of alpha =  1 The log loss is: 1.7218774105126562
# For values of best alpha =  0.001 The train log loss is: 1.0644179664426265
# For values of best alpha =  0.001 The cross validation log loss is: 1.704183682582109
# For values of best alpha =  0.001 The test log loss is: 1.7110789955069954

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1939  genes in test and cross validation data sets?
# Ans
# 1. In test data 73 out of 665 : 10.977443609022556
# 2. In cross validation data 63 out of  532 : 11.842105263157894

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(min_df=3,max_features =1000)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({256.02937420193547: 1, 178.8255688275638: 1, 141.66339038431255: 1, 130.61685836969275: 1, 129.70514159073664: 1, 118.97106131903006: 1, 118.53823413636596: 1, 115.88434636639785: 1, 113.51241245039215: 1, 111.13102271149006: 1, 108.02979300845438: 1, 94.37246169244798: 1, 90.78226911770388: 1, 89.71498223357149: 1, 81.37308006724018: 1, 80.7344471819003: 1, 80.72958065372555: 1, 79.24691328137581: 1, 79.1896690891441: 1, 75.91511034207865: 1, 73.80204276282323: 1, 73.5381937885694: 1, 72.0868160415415: 1, 70.3031560727798: 1, 69.3955398038115: 1, 67.94684943563388: 1, 67.91795608658849: 1, 66.84809342167902: 1, 65.5271883540798: 1, 65.52649136029929: 1, 65.37074306139205: 1, 65.18288994918015: 1, 61.81937007707727: 1, 60.664498106448704: 1, 59.991066799432524: 1, 57.14859726767937: 1, 56.48693616103603: 1, 56.44301612600097: 1, 52.80410702478743: 1, 51.05127447116369: 1, 50.232552651991895: 1, 50.08570982218943: 1, 50.01037404084537: 1, 49.99202696785886: 1, 49.271039981500216: 1, 48.585750418767724: 1, 47.137927136275515: 1, 46.019721038607855: 1, 46.00471404490051: 1, 45.8696794796409: 1, 45.76531334403759: 1, 44.16120878597707: 1, 44.120862282596484: 1, 44.042669630485676: 1, 43.68768306388754: 1, 43.62603470928508: 1, 43.229339117595615: 1, 43.18652130505696: 1, 43.06088342739352: 1, 42.64774046153863: 1, 41.67992223356225: 1, 41.63431524500065: 1, 41.61322966132575: 1, 41.54862143567298: 1, 41.14353160933036: 1, 41.09886738991066: 1, 40.18433744008969: 1, 40.161805845541515: 1, 39.980824924509676: 1, 39.40646897580089: 1, 39.356107458292: 1, 39.07261679588776: 1, 38.28581401745731: 1, 37.70422913050885: 1, 37.454159540546975: 1, 37.366508896425614: 1, 37.033583172067445: 1, 36.65816464607806: 1, 36.59088367147049: 1, 36.52310006480037: 1, 36.385846987404584: 1, 35.88911033677735: 1, 35.78087948028179: 1, 35.389478144027116: 1, 35.29776820171557: 1, 35.03666263683175: 1, 34.894992503331494: 1, 34.17226832362172: 1, 34.08027066808722: 1, 33.9752357253998: 1, 33.93125997132479: 1, 33.4348799242837: 1, 33.37499437467703: 1, 33.3713846034104: 1, 33.25759935550387: 1, 32.884741986756076: 1, 32.872950982880305: 1, 32.870106818983864: 1, 32.52872550315391: 1, 32.30091029972429: 1, 32.279049825964265: 1, 32.214537571783: 1, 32.137639040419636: 1, 32.12248484472536: 1, 31.982522885864817: 1, 31.830612594627542: 1, 31.437517366312758: 1, 31.403865626701602: 1, 31.309265845579827: 1, 31.094757107441318: 1, 31.075573238633453: 1, 30.892868562170147: 1, 30.873392240751738: 1, 30.708852411196563: 1, 30.244876844996345: 1, 30.16624764932496: 1, 30.133532703189264: 1, 30.10635459412905: 1, 30.05340060007565: 1, 29.849682520867837: 1, 29.58534501687297: 1, 29.43741851669551: 1, 29.399276795121708: 1, 29.382111119418855: 1, 29.012824460943225: 1, 28.967724704770777: 1, 28.751882983339193: 1, 28.712102941260333: 1, 28.582597198467397: 1, 28.387408919964344: 1, 28.38304053971371: 1, 28.063989551693115: 1, 27.932581585013214: 1, 27.91760558570822: 1, 27.903545836835942: 1, 27.763192191110612: 1, 27.62627233121134: 1, 27.286803386887534: 1, 27.260140096913688: 1, 27.10010021393685: 1, 27.09172559924369: 1, 27.07772033178126: 1, 27.004135536216943: 1, 26.69626557040692: 1, 26.640631393651308: 1, 26.57788524309255: 1, 26.238293350313683: 1, 26.176842380524505: 1, 26.009892865722428: 1, 25.864448784554536: 1, 25.862147442921763: 1, 25.58670613644829: 1, 25.57551205258733: 1, 25.567179609101135: 1, 25.465292414378354: 1, 25.406312374238382: 1, 25.38052853183484: 1, 25.348224578656467: 1, 25.32615231422459: 1, 25.012682381106835: 1, 24.90348919513389: 1, 24.881139572440954: 1, 24.83352480859926: 1, 24.783754975033794: 1, 24.760604511100407: 1, 24.755401420030502: 1, 24.71374613638795: 1, 24.55112211000573: 1, 24.46616239962583: 1, 24.453321943725452: 1, 24.332197029493777: 1, 24.320216425714204: 1, 24.20618673313482: 1, 24.158976839237873: 1, 24.058287007597173: 1, 24.01224436353292: 1, 23.96234535425655: 1, 23.89065579035313: 1, 23.788997 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.1405344402732784
# For values of alpha =  0.0001 The log loss is: 1.1748483017848006
# For values of alpha =  0.001 The log loss is: 1.5031707933474958
# For values of alpha =  0.01 The log loss is: 1.9603693895536054
# For values of alpha =  0.1 The log loss is: 2.0380504326903686
# For values of alpha =  1 The log loss is: 2.0203212757499505
# For values of best alpha =  1e-05 The train log loss is: 0.7266906882039939
# For values of best alpha =  1e-05 The cross validation log loss is: 1.1405344402732784
# For values of best alpha =  1e-05 The test log loss is: 1.0769412990430898

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = CountVectorizer(min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 3.372 % of word of test data appeared in train data
# 3.757 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer()
    var_count_vec = TfidfVectorizer()
    text_count_vec = TfidfVectorizer(min_df=3,max_features=1000)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 3185)
# (number of data points * number of features) in test data =  (665, 3185)
# (number of data points * number of features) in cross validation data = (532, 3185)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# ### CountVectorizer with bigram and unigram

# %%
text_vectorizer = CountVectorizer(min_df=3,max_features=10000,ngram_range=(1, 2))
train_text_feature_onehotCoding_bigrams = text_vectorizer.fit_transform(train_df['TEXT'])
train_text_features_bigrams= text_vectorizer.get_feature_names()
# don't forget to normalize every feature
train_text_feature_onehotCoding_bigrams = normalize(train_text_feature_onehotCoding_bigrams, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding_bigrams = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding_bigrams = normalize(test_text_feature_onehotCoding_bigrams, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding_bigrams = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding_bigrams = normalize(cv_text_feature_onehotCoding_bigrams, axis=0)

# %%
train_x_onehotCoding_bigrams = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding_bigrams)).tocsr()

test_x_onehotCoding_bigrams = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding_bigrams)).tocsr()

cv_x_onehotCoding_bigrams = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding_bigrams)).tocsr()

# %%
print("One hot encoding with bigrams features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding_bigrams.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding_bigrams.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding_bigrams.shape)
# Out:
# One hot encoding with bigrams features :
# (number of data points * number of features) in train data =  (2124, 12185)
# (number of data points * number of features) in test data =  (665, 12185)
# (number of data points * number of features) in cross validation data = (532, 12185)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.2295547800859485
# for alpha = 0.0001
# Log Loss : 1.2295833212956864
# for alpha = 0.001
# Log Loss : 1.229166051741124
# for alpha = 0.1
# Log Loss : 1.2598181941022144
# for alpha = 1
# Log Loss : 1.344477184808676
# for alpha = 10
# Log Loss : 1.5522575168515775
# for alpha = 100
# Log Loss : 1.5321884544874464
# for alpha = 1000
# Log Loss : 1.5170489178551811
# For values of best alpha =  0.001 The train log loss is: 0.5242622839724329
# For values of best alpha =  0.001 The cross validation log loss is: 1.229166051741124
# For values of best alpha =  0.001 The test log loss is: 1.172832162588705

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.229166051741124
# Number of missclassified point : 0.3890977443609023
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.0554 0.0425 0.0103 0.0547 0.0299 0.715  0.0862 0.0032 0.0027]]
# Actual Class : 6
# --------------------------------------------------
# 4 Text feature [odds] present in test data point [True]
# 5 Text feature [brca] present in test data point [True]
# 6 Text feature [57] present in test data point [True]
# 7 Text feature [classified] present in test data point [True]
# 8 Text feature [deleterious] present in test data point [True]
# 11 Text feature [history] present in test data point [True]
# 12 Text feature [basis] present in test data point [True]
# 13 Text feature [combined] present in test data point [True]
# 14 Text feature [family] present in test data point [True]
# 15 Text feature [00] present in test data point [True]
# 16 Text feature [49] present in test data point [True]
# 17 Text feature [brca1] present in test data point [True]
# 18 Text feature [models] present in test data point [True]
# 19 Text feature [43] present in test data point [True]
# 20 Text feature [evidence] present in test data point [True]
# 21 Text feature [brca2] present in test data point [True]
# 22 Text feature [000] present in test data point [True]
# 23 Text feature [26] present in test data point [True]
# 24 Text feature [sequence] present in test data point [True]
# 25 Text feature [testing] present in test data point [True]
# 26 Text feature [predicted] present in test data point [True]
# 27 Text feature [31] present in test data point [True]
# 28 Text feature [model] present in test data point [True]
# 29 Text feature [56] present in test data point [True]
# 30 Text feature [expected] present in test data point [True]
# 31 Text feature [23] present in test data point [True]
# 32 Text feature [45] present in test data point [True]
# 33 Text feature [35] present in test data point [True]
# 34 Text feature [variant] present in test data point [True]
# 35 Text feature [known] present in test data point [True]
# 36 Text feature [42] present in test data point [True]
# 37 Text feature [41] present in test data point [True]
# 38 Text feature [use] present in test data point [True]
# 39 Text feature [neutral] present in test data point [True]
# 40 Text feature [ligase] present in test data point [True]
# 41 Text feature [47] present in test data point [True]
# 42 Text feature [variants] present in test data point [True]
# 43 Text feature [52] present in test data point [True]
# 44 Text feature [given] present in test data point [True]
# 45 Text feature [used] present in test data point [True]
# 46 Text feature [likely] present in test data point [True]
# 47 Text feature [bard1] present in test data point [True]
# 49 Text feature [70] present in test data point [True]
# 50 Text feature [data] present in test data point [True]
# 53 Text feature [substitutions] present in test data point [True]
# 55 Text feature [54] present in test data point [True]
# 56 Text feature [significance] present in test data point [True]
# 57 Text feature [ring] present in test data point [True]
# 58 Text feature [substitution] present in test data point [True]
# 59 Text feature [would] present in test data point [True]
# 60 Text feature [50] present in test data point [True]
# 61 Text feature [75] present in test data point [True]
# 62 Text feature [studied] present in test data point [True]
# 63 Text feature [25] present in test data point [True]
# 64 Text feature [individuals] present in test data point [True]
# 65 Text feature [39] present in test data point [True]
# 66 Text feature [conserved] present in test data point [True]
# 67 Text feature [36] present in test data point [True]
# 68 Text feature [46] present in test data point [True]
# 69 Text feature [majority] present in test data point [True]
# 70 Text feature [32] present in test data point [True]
# 72 Text feature [population] present in test data point [True]
# 73 Text feature [least] present in test data point [True]
# 74 Text feature [approach] present in test data point [True]
# 75 Text feature [24] present in test data point [True]
# 76 Text feature [proportion] present in test data point [True]
# 77 Text feature [16] present in test data point [True]
# 78 Text feature [available] present in test data point [True]
# 79 Text feature [40] present in test data point [True]
# 80 Text feature [34] present in test data point [True]
# 81 Text feature [although] present in test data point [True]
# 82 Text feature [60] present in test data point [True]
# 83 Text feature [72] present in test data point [True]
# 84 Text feature [analysis] present in test data point [True]
# 85 Text feature [vus] present in test data point [True]
# 87 Text feature [times] present in test data point [True]
# 88 Text feature [missense] present in test data point [True]
# 89 Text feature [33] present in test data point [True]
# 90 Text feature [significant] present in test data point [True]
# 91 Text feature [28] present in test data point [True]
# 92 Text feature [characteristics] present in test data point [True]
# 93 Text feature [prior] present in test data point [True]
# 95 Text feature [provide] present in test data point [True]
# 96 Text feature [information] present in test data point [True]
# 97 Text feature [number] present in test data point [True]
# 98 Text feature [overall] present in test data point [True]
# 99 Text feature [developed] present in test data point [True]
# Out of the top  100  features  87 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0605 0.0759 0.0114 0.0774 0.0335 0.0327 0.7023 0.0035 0.0029]]
# Actual Class : 4
# --------------------------------------------------
# 18 Text feature [activation] present in test data point [True]
# 21 Text feature [activated] present in test data point [True]
# 22 Text feature [kinase] present in test data point [True]
# 23 Text feature [downstream] present in test data point [True]
# 25 Text feature [cells] present in test data point [True]
# 26 Text feature [expressing] present in test data point [True]
# 28 Text feature [independent] present in test data point [True]
# 29 Text feature [also] present in test data point [True]
# 30 Text feature [signaling] present in test data point [True]
# 31 Text feature [presence] present in test data point [True]
# 32 Text feature [factor] present in test data point [True]
# 33 Text feature [10] present in test data point [True]
# 34 Text feature [growth] present in test data point [True]
# 35 Text feature [constitutive] present in test data point [True]
# 41 Text feature [treated] present in test data point [True]
# 43 Text feature [shown] present in test data point [True]
# 44 Text feature [however] present in test data point [True]
# 45 Text feature [higher] present in test data point [True]
# 46 Text feature [mutations] present in test data point [True]
# 48 Text feature [previously] present in test data point [True]
# 49 Text feature [well] present in test data point [True]
# 50 Text feature [compared] present in test data point [True]
# 51 Text feature [addition] present in test data point [True]
# 52 Text feature [similar] present in test data point [True]
# 53 Text feature [recently] present in test data point [True]
# 55 Text feature [cell] present in test data point [True]
# 56 Text feature [tyrosine] present in test data point [True]
# 57 Text feature [showed] present in test data point [True]
# 58 Text feature [found] present in test data point [True]
# 59 Text feature [may] present in test data point [True]
# 60 Text feature [activate] present in test data point [True]
# 64 Text feature [phosphorylation] present in test data point [True]
# 65 Text feature [reported] present in test data point [True]
# 66 Text feature [enhanced] present in test data point [True]
# 67 Text feature [mechanism] present in test data point [True]
# 68 Text feature [without] present in test data point [True]
# 69 Text feature [although] present in test data point [True]
# 70 Text feature [different] present in test data point [True]
# 72 Text feature [survival] present in test data point [True]
# 73 Text feature [results] present in test data point [True]
# 74 Text feature [20] present in test data point [True]
# 75 Text feature [serum] present in test data point [True]
# 76 Text feature [total] present in test data point [True]
# 77 Text feature [receptor] present in test data point [True]
# 78 Text feature [mutation] present in test data point [True]
# 79 Text feature [described] present in test data point [True]
# 80 Text feature [identified] present in test data point [True]
# 81 Text feature [constitutively] present in test data point [True]
# 82 Text feature [13] present in test data point [True]
# 83 Text feature [24] present in test data point [True]
# 84 Text feature [12] present in test data point [True]
# 89 Text feature [respectively] present in test data point [True]
# 90 Text feature [domain] present in test data point [True]
# 91 Text feature [absence] present in test data point [True]
# 93 Text feature [clinical] present in test data point [True]
# 94 Text feature [observed] present in test data point [True]
# 96 Text feature [two] present in test data point [True]
# 97 Text feature [discussion] present in test data point [True]
# 98 Text feature [demonstrated] present in test data point [True]
# 99 Text feature [using] present in test data point [True]
# Out of the top  100  features  60 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.1757760597132445
# for alpha = 11
# Log Loss : 1.1458556514576397
# for alpha = 15
# Log Loss : 1.1524571029114452
# for alpha = 21
# Log Loss : 1.1589557730919242
# for alpha = 31
# Log Loss : 1.161697346205742
# for alpha = 41
# Log Loss : 1.1612933804455365
# for alpha = 51
# Log Loss : 1.1587261303021192
# for alpha = 99
# Log Loss : 1.1709577346456672
# For values of best alpha =  11 The train log loss is: 0.6261051930704351
# For values of best alpha =  11 The cross validation log loss is: 1.1458556514576397
# For values of best alpha =  11 The test log loss is: 1.0443070006640185

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.1458556514576397
# Number of mis-classified points : 0.40225563909774437
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 4
# Actual Class : 6
# The  11  nearest neighbours of the test points belongs to classes [6 6 6 6 6 6 6 6 6 6 6]
# Fequency of nearest points : Counter({6: 11})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 4
# the k value for knn is 11 and the nearest neighbours of the test points belongs to classes [4 4 4 7 7 2 7 2 2 7 7]
# Fequency of nearest points : Counter({7: 5, 4: 3, 2: 3})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.242839729700207
# for alpha = 1e-05
# Log Loss : 1.1459012493063025
# for alpha = 0.0001
# Log Loss : 1.1008772226406203
# for alpha = 0.001
# Log Loss : 1.1171567660951705
# for alpha = 0.01
# Log Loss : 1.2541133451995703
# for alpha = 0.1
# Log Loss : 1.6638807862533662
# for alpha = 1
# Log Loss : 1.8020612454901113
# for alpha = 10
# Log Loss : 1.816049735821716
# for alpha = 100
# Log Loss : 1.8175604625203559
# For values of best alpha =  0.0001 The train log loss is: 0.4458364115988732
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1008772226406203
# For values of best alpha =  0.0001 The test log loss is: 0.9844395253707255

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.1008772226406203
# Number of mis-classified points : 0.37781954887218044
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[1.750e-02 4.400e-03 1.000e-04 1.070e-02 1.630e-02 9.492e-01 1.400e-03
#   2.000e-04 1.000e-04]]
# Actual Class : 6
# --------------------------------------------------
# 88 Text feature [ligase] present in test data point [True]
# 90 Text feature [bard1] present in test data point [True]
# 99 Text feature [values] present in test data point [True]
# 102 Text feature [showing] present in test data point [True]
# 106 Text feature [brca] present in test data point [True]
# 117 Text feature [models] present in test data point [True]
# 126 Text feature [42] present in test data point [True]
# 127 Text feature [classified] present in test data point [True]
# 128 Text feature [49] present in test data point [True]
# 129 Text feature [ring] present in test data point [True]
# 134 Text feature [57] present in test data point [True]
# 137 Text feature [significant] present in test data point [True]
# 139 Text feature [basis] present in test data point [True]
# 141 Text feature [substitutions] present in test data point [True]
# 143 Text feature [odds] present in test data point [True]
# 150 Text feature [evidence] present in test data point [True]
# 155 Text feature [000] present in test data point [True]
# 156 Text feature [substitution] present in test data point [True]
# 159 Text feature [00] present in test data point [True]
# 164 Text feature [deleterious] present in test data point [True]
# 165 Text feature [expected] present in test data point [True]
# 170 Text feature [times] present in test data point [True]
# 174 Text feature [history] present in test data point [True]
# 176 Text feature [studied] present in test data point [True]
# 182 Text feature [loss] present in test data point [True]
# 183 Text feature [observation] present in test data point [True]
# 191 Text feature [important] present in test data point [True]
# 193 Text feature [population] present in test data point [True]
# 198 Text feature [45] present in test data point [True]
# 200 Text feature [40] present in test data point [True]
# 202 Text feature [dose] present in test data point [True]
# 203 Text feature [family] present in test data point [True]
# 204 Text feature [ability] present in test data point [True]
# 208 Text feature [ci] present in test data point [True]
# 214 Text feature [distinct] present in test data point [True]
# 216 Text feature [phase] present in test data point [True]
# 223 Text feature [direct] present in test data point [True]
# 224 Text feature [brca1] present in test data point [True]
# 225 Text feature [considered] present in test data point [True]
# 226 Text feature [60] present in test data point [True]
# 227 Text feature [selection] present in test data point [True]
# 229 Text feature [status] present in test data point [True]
# 232 Text feature [site] present in test data point [True]
# 242 Text feature [contains] present in test data point [True]
# 243 Text feature [residues] present in test data point [True]
# 244 Text feature [lower] present in test data point [True]
# 246 Text feature [individuals] present in test data point [True]
# 247 Text feature [free] present in test data point [True]
# 248 Text feature [risk] present in test data point [True]
# 253 Text feature [development] present in test data point [True]
# 254 Text feature [approach] present in test data point [True]
# 257 Text feature [75] present in test data point [True]
# 262 Text feature [23] present in test data point [True]
# 264 Text feature [relatively] present in test data point [True]
# 266 Text feature [thus] present in test data point [True]
# 267 Text feature [statistical] present in test data point [True]
# 270 Text feature [screening] present in test data point [True]
# 273 Text feature [decreased] present in test data point [True]
# 274 Text feature [null] present in test data point [True]
# 280 Text feature [calculated] present in test data point [True]
# 281 Text feature [72] present in test data point [True]
# 282 Text feature [rates] present in test data point [True]
# 287 Text feature [methods] present in test data point [True]
# 289 Text feature [proportion] present in test data point [True]
# 291 Text feature [overall] present in test data point [True]
# 292 Text feature [dependent] present in test data point [True]
# 301 Text feature [affect] present in test data point [True]
# 302 Text feature [since] present in test data point [True]
# 303 Text feature [groups] present in test data point [True]
# 305 Text feature [34] present in test data point [True]
# 308 Text feature [43] present in test data point [True]
# 311 Text feature [due] present in test data point [True]
# 314 Text feature [combined] present in test data point [True]
# 317 Text feature [single] present in test data point [True]
# 319 Text feature [structural] present in test data point [True]
# 320 Text feature [clinically] present in test data point [True]
# 321 Text feature [required] present in test data point [True]
# 328 Text feature [characteristics] present in test data point [True]
# 337 Text feature [70] present in test data point [True]
# 339 Text feature [occur] present in test data point [True]
# 343 Text feature [missense] present in test data point [True]
# 348 Text feature [altered] present in test data point [True]
# 352 Text feature [associated] present in test data point [True]
# 354 Text feature [given] present in test data point [True]
# 359 Text feature [versus] present in test data point [True]
# 362 Text feature [hypothesis] present in test data point [True]
# 365 Text feature [56] present in test data point [True]
# 368 Text feature [61] present in test data point [True]
# 371 Text feature [cannot] present in test data point [True]
# 372 Text feature [47] present in test data point [True]
# 373 Text feature [region] present in test data point [True]
# 374 Text feature [information] present in test data point [True]
# 378 Text feature [type] present in test data point [True]
# 380 Text feature [binding] present in test data point [True]
# 381 Text feature [analyses] present in test data point [True]
# 382 Text feature [35] present in test data point [True]
# 383 Text feature [95] present in test data point [True]
# 385 Text feature [breast] present in test data point [True]
# 386 Text feature [average] present in test data point [True]
# 387 Text feature [conserved] present in test data point [True]
# 388 Text feature [model] present in test data point [True]
# 391 Text feature [group] present in test data point [True]
# 393 Text feature [38] present in test data point [True]
# 397 Text feature [terminal] present in test data point [True]
# 398 Text feature [acids] present in test data point [True]
# 399 Text feature [respectively] present in test data point [True]
# 400 Text feature [predicted] present in test data point [True]
# 402 Text feature [frequency] present in test data point [True]
# 403 Text feature [transcriptional] present in test data point [True]
# 404 Text feature [example] present in test data point [True]
# 406 Text feature [applied] present in test data point [True]
# 407 Text feature [21] present in test data point [True]
# 411 Text feature [51] present in test data point [True]
# 414 Text feature [neutral] present in test data point [True]
# 415 Text feature [particular] present in test data point [True]
# 416 Text feature [classification] present in test data point [True]
# 423 Text feature [none] present in test data point [True]
# 424 Text feature [distribution] present in test data point [True]
# 425 Text feature [selected] present in test data point [True]
# 426 Text feature [interestingly] present in test data point [True]
# 430 Text feature [difference] present in test data point [True]
# 432 Text feature [17] present in test data point [True]
# 433 Text feature [american] present in test data point [True]
# 434 Text feature [residue] present in test data point [True]
# 437 Text feature [least] present in test data point [True]
# 439 Text feature [testing] present in test data point [True]
# 441 Text feature [terminus] present in test data point [True]
# 443 Text feature [response] present in test data point [True]
# 444 Text feature [shown] present in test data point [True]
# 449 Text feature [31] present in test data point [True]
# 450 Text feature [54] present in test data point [True]
# 452 Text feature [use] present in test data point [True]
# 453 Text feature [higher] present in test data point [True]
# 457 Text feature [20] present in test data point [True]
# 460 Text feature [types] present in test data point [True]
# 462 Text feature [nucleotide] present in test data point [True]
# 463 Text feature [44] present in test data point [True]
# 464 Text feature [core] present in test data point [True]
# 468 Text feature [value] present in test data point [True]
# 474 Text feature [set] present in test data point [True]
# 478 Text feature [association] present in test data point [True]
# 479 Text feature [factors] present in test data point [True]
# 480 Text feature [52] present in test data point [True]
# 481 Text feature [therefore] present in test data point [True]
# 484 Text feature [following] present in test data point [True]
# 487 Text feature [multiple] present in test data point [True]
# 490 Text feature [structure] present in test data point [True]
# 492 Text feature [majority] present in test data point [True]
# 493 Text feature [six] present in test data point [True]
# 498 Text feature [12] present in test data point [True]
# Out of the top  500  features  150 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0222 0.1394 0.0102 0.1588 0.0286 0.0118 0.6174 0.0068 0.0048]]
# Actual Class : 4
# --------------------------------------------------
# 7 Text feature [constitutive] present in test data point [True]
# 13 Text feature [downstream] present in test data point [True]
# 14 Text feature [activation] present in test data point [True]
# 15 Text feature [enhanced] present in test data point [True]
# 23 Text feature [3t3] present in test data point [True]
# 41 Text feature [serum] present in test data point [True]
# 42 Text feature [activate] present in test data point [True]
# 49 Text feature [factor] present in test data point [True]
# 50 Text feature [oncogene] present in test data point [True]
# 53 Text feature [transforming] present in test data point [True]
# 55 Text feature [transformed] present in test data point [True]
# 73 Text feature [activated] present in test data point [True]
# 103 Text feature [akt] present in test data point [True]
# 104 Text feature [coding] present in test data point [True]
# 117 Text feature [expressing] present in test data point [True]
# 120 Text feature [approximately] present in test data point [True]
# 167 Text feature [extracellular] present in test data point [True]
# 169 Text feature [survival] present in test data point [True]
# 181 Text feature [carcinoma] present in test data point [True]
# 183 Text feature [conditions] present in test data point [True]
# 195 Text feature [concentrations] present in test data point [True]
# 203 Text feature [cdna] present in test data point [True]
# 205 Text feature [phosphorylated] present in test data point [True]
# 277 Text feature [2b] present in test data point [True]
# 278 Text feature [2a] present in test data point [True]
# 289 Text feature [nih] present in test data point [True]
# 290 Text feature [promoter] present in test data point [True]
# 295 Text feature [24] present in test data point [True]
# 296 Text feature [medium] present in test data point [True]
# 310 Text feature [derived] present in test data point [True]
# 328 Text feature [amplification] present in test data point [True]
# 339 Text feature [hours] present in test data point [True]
# 349 Text feature [mechanisms] present in test data point [True]
# 355 Text feature [tyrosine] present in test data point [True]
# 381 Text feature [phosphorylation] present in test data point [True]
# 400 Text feature [independent] present in test data point [True]
# 401 Text feature [ras] present in test data point [True]
# 408 Text feature [without] present in test data point [True]
# 409 Text feature [pathways] present in test data point [True]
# 436 Text feature [total] present in test data point [True]
# 451 Text feature [gain] present in test data point [True]
# 478 Text feature [signaling] present in test data point [True]
# Out of the top  500  features  42 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.2380386502267076
# for alpha = 1e-05
# Log Loss : 1.174715756361993
# for alpha = 0.0001
# Log Loss : 1.1212289454580644
# for alpha = 0.001
# Log Loss : 1.1800138931797572
# for alpha = 0.01
# Log Loss : 1.3776565515963004
# for alpha = 0.1
# Log Loss : 1.6852373382217598
# for alpha = 1
# Log Loss : 1.787984835961603
# For values of best alpha =  0.0001 The train log loss is: 0.44433736932811074
# For values of best alpha =  0.0001 The cross validation log loss is: 1.1212289454580644
# For values of best alpha =  0.0001 The test log loss is: 1.0101054634849358

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.1212289454580644
# Number of mis-classified points : 0.3815789473684211
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[2.400e-02 4.500e-03 1.000e-04 1.260e-02 1.430e-02 9.416e-01 2.600e-03
#   3.000e-04 0.000e+00]]
# Actual Class : 6
# --------------------------------------------------
# 87 Text feature [ligase] present in test data point [True]
# 89 Text feature [bard1] present in test data point [True]
# 98 Text feature [values] present in test data point [True]
# 103 Text feature [brca] present in test data point [True]
# 107 Text feature [showing] present in test data point [True]
# 113 Text feature [models] present in test data point [True]
# 123 Text feature [classified] present in test data point [True]
# 124 Text feature [ring] present in test data point [True]
# 127 Text feature [49] present in test data point [True]
# 128 Text feature [42] present in test data point [True]
# 129 Text feature [57] present in test data point [True]
# 139 Text feature [substitutions] present in test data point [True]
# 140 Text feature [basis] present in test data point [True]
# 141 Text feature [odds] present in test data point [True]
# 144 Text feature [significant] present in test data point [True]
# 147 Text feature [substitution] present in test data point [True]
# 150 Text feature [evidence] present in test data point [True]
# 151 Text feature [000] present in test data point [True]
# 153 Text feature [00] present in test data point [True]
# 158 Text feature [expected] present in test data point [True]
# 164 Text feature [deleterious] present in test data point [True]
# 172 Text feature [history] present in test data point [True]
# 173 Text feature [times] present in test data point [True]
# 174 Text feature [studied] present in test data point [True]
# 181 Text feature [loss] present in test data point [True]
# 189 Text feature [observation] present in test data point [True]
# 191 Text feature [family] present in test data point [True]
# 196 Text feature [population] present in test data point [True]
# 197 Text feature [important] present in test data point [True]
# 203 Text feature [45] present in test data point [True]
# 206 Text feature [40] present in test data point [True]
# 208 Text feature [ci] present in test data point [True]
# 209 Text feature [dose] present in test data point [True]
# 213 Text feature [direct] present in test data point [True]
# 219 Text feature [60] present in test data point [True]
# 221 Text feature [considered] present in test data point [True]
# 222 Text feature [site] present in test data point [True]
# 226 Text feature [distinct] present in test data point [True]
# 227 Text feature [residues] present in test data point [True]
# 229 Text feature [ability] present in test data point [True]
# 233 Text feature [phase] present in test data point [True]
# 237 Text feature [brca1] present in test data point [True]
# 241 Text feature [development] present in test data point [True]
# 243 Text feature [risk] present in test data point [True]
# 244 Text feature [status] present in test data point [True]
# 246 Text feature [individuals] present in test data point [True]
# 247 Text feature [free] present in test data point [True]
# 248 Text feature [selection] present in test data point [True]
# 249 Text feature [75] present in test data point [True]
# 250 Text feature [lower] present in test data point [True]
# 251 Text feature [approach] present in test data point [True]
# 254 Text feature [contains] present in test data point [True]
# 255 Text feature [statistical] present in test data point [True]
# 256 Text feature [relatively] present in test data point [True]
# 265 Text feature [screening] present in test data point [True]
# 276 Text feature [23] present in test data point [True]
# 279 Text feature [null] present in test data point [True]
# 283 Text feature [decreased] present in test data point [True]
# 289 Text feature [calculated] present in test data point [True]
# 290 Text feature [72] present in test data point [True]
# 293 Text feature [proportion] present in test data point [True]
# 299 Text feature [overall] present in test data point [True]
# 300 Text feature [43] present in test data point [True]
# 302 Text feature [since] present in test data point [True]
# 305 Text feature [thus] present in test data point [True]
# 307 Text feature [methods] present in test data point [True]
# 310 Text feature [structural] present in test data point [True]
# 313 Text feature [rates] present in test data point [True]
# 314 Text feature [clinically] present in test data point [True]
# 316 Text feature [34] present in test data point [True]
# 318 Text feature [affect] present in test data point [True]
# 321 Text feature [characteristics] present in test data point [True]
# 322 Text feature [70] present in test data point [True]
# 323 Text feature [single] present in test data point [True]
# 328 Text feature [groups] present in test data point [True]
# 333 Text feature [due] present in test data point [True]
# 335 Text feature [56] present in test data point [True]
# 337 Text feature [dependent] present in test data point [True]
# 338 Text feature [required] present in test data point [True]
# 347 Text feature [occur] present in test data point [True]
# 349 Text feature [combined] present in test data point [True]
# 352 Text feature [breast] present in test data point [True]
# 356 Text feature [versus] present in test data point [True]
# 361 Text feature [missense] present in test data point [True]
# 362 Text feature [information] present in test data point [True]
# 364 Text feature [47] present in test data point [True]
# 365 Text feature [given] present in test data point [True]
# 366 Text feature [altered] present in test data point [True]
# 371 Text feature [associated] present in test data point [True]
# 372 Text feature [region] present in test data point [True]
# 375 Text feature [binding] present in test data point [True]
# 378 Text feature [95] present in test data point [True]
# 379 Text feature [particular] present in test data point [True]
# 380 Text feature [conserved] present in test data point [True]
# 381 Text feature [61] present in test data point [True]
# 383 Text feature [hypothesis] present in test data point [True]
# 384 Text feature [35] present in test data point [True]
# 387 Text feature [21] present in test data point [True]
# 388 Text feature [respectively] present in test data point [True]
# 389 Text feature [model] present in test data point [True]
# 392 Text feature [terminal] present in test data point [True]
# 393 Text feature [38] present in test data point [True]
# 395 Text feature [predicted] present in test data point [True]
# 396 Text feature [analyses] present in test data point [True]
# 397 Text feature [group] present in test data point [True]
# 398 Text feature [cannot] present in test data point [True]
# 399 Text feature [applied] present in test data point [True]
# 401 Text feature [acids] present in test data point [True]
# 404 Text feature [frequency] present in test data point [True]
# 406 Text feature [transcriptional] present in test data point [True]
# 408 Text feature [classification] present in test data point [True]
# 410 Text feature [51] present in test data point [True]
# 413 Text feature [residue] present in test data point [True]
# 414 Text feature [none] present in test data point [True]
# 415 Text feature [average] present in test data point [True]
# 416 Text feature [core] present in test data point [True]
# 418 Text feature [type] present in test data point [True]
# 419 Text feature [distribution] present in test data point [True]
# 420 Text feature [testing] present in test data point [True]
# 422 Text feature [17] present in test data point [True]
# 428 Text feature [selected] present in test data point [True]
# 430 Text feature [54] present in test data point [True]
# 432 Text feature [52] present in test data point [True]
# 433 Text feature [terminus] present in test data point [True]
# 434 Text feature [nucleotide] present in test data point [True]
# 435 Text feature [example] present in test data point [True]
# 436 Text feature [interestingly] present in test data point [True]
# 438 Text feature [structure] present in test data point [True]
# 443 Text feature [44] present in test data point [True]
# 445 Text feature [response] present in test data point [True]
# 446 Text feature [set] present in test data point [True]
# 448 Text feature [difference] present in test data point [True]
# 450 Text feature [american] present in test data point [True]
# 451 Text feature [least] present in test data point [True]
# 454 Text feature [ovarian] present in test data point [True]
# 456 Text feature [neutral] present in test data point [True]
# 458 Text feature [31] present in test data point [True]
# 459 Text feature [value] present in test data point [True]
# 462 Text feature [shown] present in test data point [True]
# 465 Text feature [use] present in test data point [True]
# 467 Text feature [types] present in test data point [True]
# 471 Text feature [20] present in test data point [True]
# 474 Text feature [higher] present in test data point [True]
# 475 Text feature [multiple] present in test data point [True]
# 477 Text feature [following] present in test data point [True]
# 478 Text feature [majority] present in test data point [True]
# 486 Text feature [factors] present in test data point [True]
# 489 Text feature [half] present in test data point [True]
# 491 Text feature [six] present in test data point [True]
# 495 Text feature [therefore] present in test data point [True]
# 496 Text feature [confer] present in test data point [True]
# 497 Text feature [suggests] present in test data point [True]
# 499 Text feature [including] present in test data point [True]
# Out of the top  500  features  153 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0225 0.1408 0.0101 0.1746 0.0312 0.0116 0.6001 0.0059 0.0033]]
# Actual Class : 4
# --------------------------------------------------
# 18 Text feature [constitutive] present in test data point [True]
# 24 Text feature [downstream] present in test data point [True]
# 25 Text feature [enhanced] present in test data point [True]
# 29 Text feature [activation] present in test data point [True]
# 47 Text feature [factor] present in test data point [True]
# 48 Text feature [3t3] present in test data point [True]
# 61 Text feature [activate] present in test data point [True]
# 69 Text feature [serum] present in test data point [True]
# 85 Text feature [transforming] present in test data point [True]
# 89 Text feature [coding] present in test data point [True]
# 102 Text feature [transformed] present in test data point [True]
# 113 Text feature [oncogene] present in test data point [True]
# 131 Text feature [approximately] present in test data point [True]
# 145 Text feature [activated] present in test data point [True]
# 156 Text feature [akt] present in test data point [True]
# 186 Text feature [concentrations] present in test data point [True]
# 188 Text feature [carcinoma] present in test data point [True]
# 202 Text feature [expressing] present in test data point [True]
# 205 Text feature [phosphorylated] present in test data point [True]
# 229 Text feature [conditions] present in test data point [True]
# 241 Text feature [cdna] present in test data point [True]
# 245 Text feature [survival] present in test data point [True]
# 251 Text feature [extracellular] present in test data point [True]
# 264 Text feature [2b] present in test data point [True]
# 267 Text feature [24] present in test data point [True]
# 279 Text feature [promoter] present in test data point [True]
# 290 Text feature [derived] present in test data point [True]
# 301 Text feature [2a] present in test data point [True]
# 326 Text feature [medium] present in test data point [True]
# 347 Text feature [without] present in test data point [True]
# 357 Text feature [mechanisms] present in test data point [True]
# 369 Text feature [nih] present in test data point [True]
# 370 Text feature [hours] present in test data point [True]
# 382 Text feature [phosphorylation] present in test data point [True]
# 390 Text feature [amplification] present in test data point [True]
# 395 Text feature [ras] present in test data point [True]
# 410 Text feature [properties] present in test data point [True]
# 414 Text feature [gain] present in test data point [True]
# 454 Text feature [total] present in test data point [True]
# 471 Text feature [membrane] present in test data point [True]
# Out of the top  500  features  40 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.2078259679065073
# for C = 0.0001
# Log Loss : 1.1232224033995737
# for C = 0.001
# Log Loss : 1.1194303298192712
# for C = 0.01
# Log Loss : 1.3418907991916766
# for C = 0.1
# Log Loss : 1.661518430721373
# for C = 1
# Log Loss : 1.8178755074095279
# for C = 10
# Log Loss : 1.817875445434171
# for C = 100
# Log Loss : 1.8178755991103728
# For values of best alpha =  0.001 The train log loss is: 0.5454955431637388
# For values of best alpha =  0.001 The cross validation log loss is: 1.1194303298192712
# For values of best alpha =  0.001 The test log loss is: 1.0613679405240943

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1194303298192712
# Number of mis-classified points : 0.37030075187969924
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[4.030e-02 4.040e-02 1.100e-03 6.480e-02 1.800e-02 7.884e-01 4.600e-02
#   5.000e-04 5.000e-04]]
# Actual Class : 6
# --------------------------------------------------
# 1 Text feature [ligase] present in test data point [True]
# 3 Text feature [bard1] present in test data point [True]
# 6 Text feature [brca] present in test data point [True]
# 7 Text feature [classified] present in test data point [True]
# 8 Text feature [substitutions] present in test data point [True]
# 9 Text feature [ring] present in test data point [True]
# 10 Text feature [showing] present in test data point [True]
# 12 Text feature [substitution] present in test data point [True]
# 13 Text feature [models] present in test data point [True]
# 116 Text feature [odds] present in test data point [True]
# 118 Text feature [57] present in test data point [True]
# 119 Text feature [expected] present in test data point [True]
# 120 Text feature [studied] present in test data point [True]
# 122 Text feature [values] present in test data point [True]
# 123 Text feature [deleterious] present in test data point [True]
# 132 Text feature [00] present in test data point [True]
# 133 Text feature [basis] present in test data point [True]
# 151 Text feature [49] present in test data point [True]
# 152 Text feature [history] present in test data point [True]
# 153 Text feature [loss] present in test data point [True]
# 160 Text feature [000] present in test data point [True]
# 163 Text feature [significant] present in test data point [True]
# 165 Text feature [42] present in test data point [True]
# 166 Text feature [times] present in test data point [True]
# 167 Text feature [individuals] present in test data point [True]
# 169 Text feature [majority] present in test data point [True]
# 171 Text feature [evidence] present in test data point [True]
# 172 Text feature [characteristics] present in test data point [True]
# 174 Text feature [predicted] present in test data point [True]
# 175 Text feature [site] present in test data point [True]
# 177 Text feature [family] present in test data point [True]
# 181 Text feature [status] present in test data point [True]
# 183 Text feature [lower] present in test data point [True]
# 186 Text feature [45] present in test data point [True]
# 189 Text feature [free] present in test data point [True]
# 190 Text feature [none] present in test data point [True]
# 191 Text feature [population] present in test data point [True]
# 193 Text feature [40] present in test data point [True]
# 204 Text feature [brca1] present in test data point [True]
# 209 Text feature [occur] present in test data point [True]
# 211 Text feature [direct] present in test data point [True]
# 212 Text feature [43] present in test data point [True]
# 213 Text feature [56] present in test data point [True]
# 216 Text feature [development] present in test data point [True]
# 217 Text feature [60] present in test data point [True]
# 218 Text feature [clinically] present in test data point [True]
# 221 Text feature [binding] present in test data point [True]
# 222 Text feature [proportion] present in test data point [True]
# 225 Text feature [model] present in test data point [True]
# 252 Text feature [selection] present in test data point [True]
# 254 Text feature [altered] present in test data point [True]
# 255 Text feature [hypothesis] present in test data point [True]
# 257 Text feature [screening] present in test data point [True]
# 259 Text feature [required] present in test data point [True]
# 260 Text feature [acids] present in test data point [True]
# 261 Text feature [single] present in test data point [True]
# 262 Text feature [23] present in test data point [True]
# 263 Text feature [likely] present in test data point [True]
# 267 Text feature [versus] present in test data point [True]
# 268 Text feature [overall] present in test data point [True]
# 270 Text feature [thus] present in test data point [True]
# 272 Text feature [21] present in test data point [True]
# 273 Text feature [subset] present in test data point [True]
# 274 Text feature [null] present in test data point [True]
# 277 Text feature [34] present in test data point [True]
# 278 Text feature [confer] present in test data point [True]
# 279 Text feature [neutral] present in test data point [True]
# 280 Text feature [35] present in test data point [True]
# 282 Text feature [observation] present in test data point [True]
# 302 Text feature [distinct] present in test data point [True]
# 304 Text feature [given] present in test data point [True]
# 305 Text feature [dose] present in test data point [True]
# 307 Text feature [missense] present in test data point [True]
# 309 Text feature [significance] present in test data point [True]
# 310 Text feature [tumor] present in test data point [True]
# 314 Text feature [frequency] present in test data point [True]
# 315 Text feature [rates] present in test data point [True]
# 321 Text feature [distribution] present in test data point [True]
# 322 Text feature [normal] present in test data point [True]
# 326 Text feature [prior] present in test data point [True]
# 328 Text feature [31] present in test data point [True]
# 329 Text feature [changes] present in test data point [True]
# 340 Text feature [41] present in test data point [True]
# 341 Text feature [database] present in test data point [True]
# 342 Text feature [44] present in test data point [True]
# 344 Text feature [approach] present in test data point [True]
# 345 Text feature [statistical] present in test data point [True]
# 347 Text feature [set] present in test data point [True]
# 349 Text feature [combined] present in test data point [True]
# 350 Text feature [61] present in test data point [True]
# 353 Text feature [relatively] present in test data point [True]
# 354 Text feature [72] present in test data point [True]
# 356 Text feature [decreased] present in test data point [True]
# 357 Text feature [fig] present in test data point [True]
# 360 Text feature [26] present in test data point [True]
# 361 Text feature [associated] present in test data point [True]
# 362 Text feature [independent] present in test data point [True]
# 363 Text feature [affect] present in test data point [True]
# 365 Text feature [applied] present in test data point [True]
# 367 Text feature [ovarian] present in test data point [True]
# 370 Text feature [factors] present in test data point [True]
# 372 Text feature [examined] present in test data point [True]
# 374 Text feature [acid] present in test data point [True]
# 375 Text feature [methods] present in test data point [True]
# 376 Text feature [variants] present in test data point [True]
# 378 Text feature [classification] present in test data point [True]
# 382 Text feature [breast] present in test data point [True]
# 385 Text feature [information] present in test data point [True]
# 388 Text feature [amino] present in test data point [True]
# 389 Text feature [52] present in test data point [True]
# 390 Text feature [75] present in test data point [True]
# 391 Text feature [01] present in test data point [True]
# 392 Text feature [use] present in test data point [True]
# 393 Text feature [since] present in test data point [True]
# 394 Text feature [risk] present in test data point [True]
# 400 Text feature [would] present in test data point [True]
# 402 Text feature [20] present in test data point [True]
# 405 Text feature [type] present in test data point [True]
# 406 Text feature [sequence] present in test data point [True]
# 407 Text feature [considered] present in test data point [True]
# 408 Text feature [residues] present in test data point [True]
# 409 Text feature [ratio] present in test data point [True]
# 412 Text feature [group] present in test data point [True]
# 413 Text feature [suggests] present in test data point [True]
# 414 Text feature [generated] present in test data point [True]
# 415 Text feature [average] present in test data point [True]
# 416 Text feature [47] present in test data point [True]
# 417 Text feature [many] present in test data point [True]
# 418 Text feature [phase] present in test data point [True]
# 419 Text feature [observations] present in test data point [True]
# 422 Text feature [important] present in test data point [True]
# 425 Text feature [nucleotide] present in test data point [True]
# 426 Text feature [calculated] present in test data point [True]
# 427 Text feature [identified] present in test data point [True]
# 428 Text feature [reported] present in test data point [True]
# 429 Text feature [test] present in test data point [True]
# 430 Text feature [types] present in test data point [True]
# 433 Text feature [testing] present in test data point [True]
# 435 Text feature [38] present in test data point [True]
# 436 Text feature [response] present in test data point [True]
# 437 Text feature [targeted] present in test data point [True]
# 438 Text feature [differences] present in test data point [True]
# 439 Text feature [require] present in test data point [True]
# 440 Text feature [shows] present in test data point [True]
# 441 Text feature [17] present in test data point [True]
# 442 Text feature [particular] present in test data point [True]
# 443 Text feature [12] present in test data point [True]
# 445 Text feature [disease] present in test data point [True]
# 446 Text feature [therapeutic] present in test data point [True]
# 450 Text feature [five] present in test data point [True]
# 451 Text feature [individual] present in test data point [True]
# 453 Text feature [ability] present in test data point [True]
# 454 Text feature [least] present in test data point [True]
# 455 Text feature [value] present in test data point [True]
# 456 Text feature [region] present in test data point [True]
# 457 Text feature [51] present in test data point [True]
# 458 Text feature [conserved] present in test data point [True]
# 459 Text feature [used] present in test data point [True]
# 461 Text feature [therefore] present in test data point [True]
# 462 Text feature [american] present in test data point [True]
# 464 Text feature [54] present in test data point [True]
# 465 Text feature [dependent] present in test data point [True]
# 466 Text feature [clinical] present in test data point [True]
# 471 Text feature [groups] present in test data point [True]
# 474 Text feature [number] present in test data point [True]
# 475 Text feature [variant] present in test data point [True]
# 476 Text feature [fact] present in test data point [True]
# 477 Text feature [half] present in test data point [True]
# 478 Text feature [ci] present in test data point [True]
# 481 Text feature [wild] present in test data point [True]
# 487 Text feature [terminus] present in test data point [True]
# 488 Text feature [whether] present in test data point [True]
# 489 Text feature [including] present in test data point [True]
# 490 Text feature [structural] present in test data point [True]
# 491 Text feature [within] present in test data point [True]
# 495 Text feature [lack] present in test data point [True]
# 496 Text feature [analysis] present in test data point [True]
# Out of the top  500  features  177 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0893 0.0935 0.0156 0.1465 0.0473 0.0239 0.5722 0.0061 0.0055]]
# Actual Class : 4
# --------------------------------------------------
# 8 Text feature [constitutive] present in test data point [True]
# 20 Text feature [activation] present in test data point [True]
# 22 Text feature [enhanced] present in test data point [True]
# 26 Text feature [3t3] present in test data point [True]
# 34 Text feature [akt] present in test data point [True]
# 36 Text feature [downstream] present in test data point [True]
# 38 Text feature [activate] present in test data point [True]
# 42 Text feature [factor] present in test data point [True]
# 48 Text feature [approximately] present in test data point [True]
# 54 Text feature [nih] present in test data point [True]
# 56 Text feature [serum] present in test data point [True]
# 57 Text feature [expressing] present in test data point [True]
# 59 Text feature [coding] present in test data point [True]
# 62 Text feature [activated] present in test data point [True]
# 63 Text feature [oncogene] present in test data point [True]
# 202 Text feature [phosphorylated] present in test data point [True]
# 204 Text feature [transformed] present in test data point [True]
# 205 Text feature [extracellular] present in test data point [True]
# 261 Text feature [2b] present in test data point [True]
# 262 Text feature [gain] present in test data point [True]
# 294 Text feature [24] present in test data point [True]
# 295 Text feature [transforming] present in test data point [True]
# 297 Text feature [independent] present in test data point [True]
# 316 Text feature [concentrations] present in test data point [True]
# 334 Text feature [cdna] present in test data point [True]
# 335 Text feature [tyrosine] present in test data point [True]
# 357 Text feature [without] present in test data point [True]
# 359 Text feature [mutants] present in test data point [True]
# 361 Text feature [ret] present in test data point [True]
# 363 Text feature [phosphorylation] present in test data point [True]
# 365 Text feature [domain] present in test data point [True]
# 402 Text feature [mechanisms] present in test data point [True]
# 407 Text feature [2a] present in test data point [True]
# 409 Text feature [hours] present in test data point [True]
# 410 Text feature [amplification] present in test data point [True]
# 411 Text feature [survival] present in test data point [True]
# 414 Text feature [promoter] present in test data point [True]
# 440 Text feature [derived] present in test data point [True]
# 442 Text feature [membrane] present in test data point [True]
# 447 Text feature [wt] present in test data point [True]
# 448 Text feature [carcinoma] present in test data point [True]
# 469 Text feature [signaling] present in test data point [True]
# 473 Text feature [form] present in test data point [True]
# 478 Text feature [previously] present in test data point [True]
# Out of the top  500  features  44 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2642775816946927
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.3044858040345575
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2515173075232506
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.2882278145769392
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.244968401874799
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.282523269688031
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2445345443284646
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.2740150901724754
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.2462196144991404
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.272776368106483
# For values of best estimator =  1000 The train log loss is: 0.8487637121935462
# For values of best estimator =  1000 The cross validation log loss is: 1.2445345443284646
# For values of best estimator =  1000 The test log loss is: 1.19132006190891

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.2445345443284646
# Number of mis-classified points : 0.4342105263157895
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[2.350e-02 2.900e-03 4.800e-03 1.460e-02 8.400e-02 8.606e-01 7.500e-03
#   1.800e-03 4.000e-04]]
# Actual Class : 6
# --------------------------------------------------
# 3 Text feature [activation] present in test data point [True]
# 6 Text feature [function] present in test data point [True]
# 7 Text feature [loss] present in test data point [True]
# 11 Text feature [brca1] present in test data point [True]
# 14 Text feature [missense] present in test data point [True]
# 15 Text feature [classified] present in test data point [True]
# 19 Text feature [yeast] present in test data point [True]
# 20 Text feature [deleterious] present in test data point [True]
# 21 Text feature [functional] present in test data point [True]
# 22 Text feature [neutral] present in test data point [True]
# 26 Text feature [protein] present in test data point [True]
# 28 Text feature [therapeutic] present in test data point [True]
# 30 Text feature [variants] present in test data point [True]
# 32 Text feature [cells] present in test data point [True]
# 34 Text feature [pathogenic] present in test data point [True]
# 35 Text feature [brca2] present in test data point [True]
# 36 Text feature [brca] present in test data point [True]
# 42 Text feature [sensitivity] present in test data point [True]
# 44 Text feature [odds] present in test data point [True]
# 48 Text feature [patients] present in test data point [True]
# 51 Text feature [brct] present in test data point [True]
# 53 Text feature [57] present in test data point [True]
# 57 Text feature [expression] present in test data point [True]
# 61 Text feature [vus] present in test data point [True]
# 64 Text feature [predicted] present in test data point [True]
# 65 Text feature [information] present in test data point [True]
# 68 Text feature [proteins] present in test data point [True]
# 69 Text feature [variant] present in test data point [True]
# 70 Text feature [repair] present in test data point [True]
# 73 Text feature [functions] present in test data point [True]
# 75 Text feature [ovarian] present in test data point [True]
# 76 Text feature [ring] present in test data point [True]
# 77 Text feature [type] present in test data point [True]
# 79 Text feature [response] present in test data point [True]
# 80 Text feature [null] present in test data point [True]
# 82 Text feature [potential] present in test data point [True]
# 84 Text feature [risk] present in test data point [True]
# 88 Text feature [assays] present in test data point [True]
# 89 Text feature [clinical] present in test data point [True]
# 91 Text feature [dna] present in test data point [True]
# 98 Text feature [patient] present in test data point [True]
# 99 Text feature [activity] present in test data point [True]
# Out of the top  100  features  42 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0719 0.0953 0.0279 0.215  0.0562 0.0439 0.4812 0.0068 0.0018]]
# Actuall Class : 4
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 2 Text feature [tyrosine] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 4 Text feature [phosphorylation] present in test data point [True]
# 6 Text feature [function] present in test data point [True]
# 7 Text feature [loss] present in test data point [True]
# 9 Text feature [constitutive] present in test data point [True]
# 13 Text feature [activated] present in test data point [True]
# 14 Text feature [missense] present in test data point [True]
# 15 Text feature [classified] present in test data point [True]
# 17 Text feature [stability] present in test data point [True]
# 18 Text feature [erk] present in test data point [True]
# 21 Text feature [functional] present in test data point [True]
# 23 Text feature [treated] present in test data point [True]
# 24 Text feature [extracellular] present in test data point [True]
# 25 Text feature [growth] present in test data point [True]
# 26 Text feature [protein] present in test data point [True]
# 29 Text feature [receptor] present in test data point [True]
# 31 Text feature [constitutively] present in test data point [True]
# 32 Text feature [cells] present in test data point [True]
# 37 Text feature [akt] present in test data point [True]
# 43 Text feature [signaling] present in test data point [True]
# 48 Text feature [patients] present in test data point [True]
# 49 Text feature [transforming] present in test data point [True]
# 52 Text feature [survival] present in test data point [True]
# 54 Text feature [cell] present in test data point [True]
# 55 Text feature [activate] present in test data point [True]
# 57 Text feature [expression] present in test data point [True]
# 58 Text feature [3t3] present in test data point [True]
# 63 Text feature [resistance] present in test data point [True]
# 68 Text feature [proteins] present in test data point [True]
# 71 Text feature [kinases] present in test data point [True]
# 77 Text feature [type] present in test data point [True]
# 83 Text feature [expressing] present in test data point [True]
# 86 Text feature [nuclear] present in test data point [True]
# 89 Text feature [clinical] present in test data point [True]
# 91 Text feature [dna] present in test data point [True]
# 95 Text feature [ras] present in test data point [True]
# 96 Text feature [lines] present in test data point [True]
# 97 Text feature [downstream] present in test data point [True]
# 99 Text feature [activity] present in test data point [True]
# Out of the top  100  features  41 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 2.0533265740734086
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.69992074232754
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.6339521163926476
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.9170287771616337
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.7218072903961799
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.6042621615343757
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.5327486220267263
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.6492540585014215
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.6636975311754052
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.6082685587681755
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.423350977516631
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.6515182791685517
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.6889361608939457
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.6344247549179303
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.4550855412850852
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.6528442411498083
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.7482082224202355
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.6831004866137798
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.461195189569479
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.6877471581456205
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.7258800602491804
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.6744294282012135
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.4332629548932667
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.6719486360327012
# For values of best alpha =  100 The train log loss is: 0.05912533916428778
# For values of best alpha =  100 The cross validation log loss is: 1.423350977516631
# For values of best alpha =  100 The test log loss is: 1.363661112072634

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.423350977516631
# Number of mis-classified points : 0.5338345864661654
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.016  0.0032 0.0162 0.0121 0.0685 0.8707 0.0026 0.0064 0.0043]]
# Actual Class : 6
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0286 0.2744 0.1864 0.1467 0.036  0.0772 0.2126 0.025  0.0131]]
# Actual Class : 4
# --------------------------------------------------
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Gene is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Variation is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Variation is important feature
# Text is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.12
# Support vector machines : Log Loss: 1.82
# Naive Bayes : Log Loss: 1.23
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.178
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.032
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.513
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.210
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.438
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.897

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.5408909785379405
# Log loss (CV) on the stacking classifier : 1.2101010188146915
# Log loss (test) on the stacking classifier : 1.1511167194602463
# Number of missclassified point : 0.37593984962406013
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.8264421063309145
# Log loss (CV) on the VotingClassifier : 1.2316175319035945
# Log loss (test) on the VotingClassifier : 1.188440170383232
# Number of missclassified point : 0.3699248120300752
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>4.8 Logistic Regression with bigrams </h2>

# %% [markdown]
# <h3>4.8.1 With Class balancing</h3>

# %% [markdown]
# <h4>4.8.1.1 Hyper parameter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_bigrams, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_bigrams, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_bigrams)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_bigrams, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_bigrams, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_bigrams)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_bigrams)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_bigrams)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.2024425563328112
# for alpha = 1e-05
# Log Loss : 1.1956809970808393
# for alpha = 0.0001
# Log Loss : 1.0699611210639894
# for alpha = 0.001
# Log Loss : 1.0661646268572804
# for alpha = 0.01
# Log Loss : 1.1979046743309918
# for alpha = 0.1
# Log Loss : 1.685809679272873
# for alpha = 1
# Log Loss : 1.777858550491557
# for alpha = 10
# Log Loss : 1.7873162633035382
# for alpha = 100
# Log Loss : 1.7882748859330584
# For values of best alpha =  0.001 The train log loss is: 0.5914222385038571
# For values of best alpha =  0.001 The cross validation log loss is: 1.0661646268572804
# For values of best alpha =  0.001 The test log loss is: 0.9505489888370642

# %% [markdown]
# <h4>4.8.1.2 Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_bigrams, train_y, cv_x_onehotCoding_bigrams, cv_y, clf)
# Out:
# Log loss : 1.0661646268572804
# Number of mis-classified points : 0.36654135338345867
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.8.1.3 Feature Importance</h4>

# %%
def get_imp_feature_names(indices,text , removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features_bigrams[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h4>4.8.1.3.1 Correctly classified point</h4>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_bigrams,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_bigrams[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_bigrams[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[1.970e-02 2.400e-03 7.000e-04 3.800e-03 3.930e-02 9.315e-01 4.000e-04
#   2.300e-03 0.000e+00]]
# Actual Class : 6
# --------------------------------------------------
# 19 Text feature [african] present in test data point [True]
# 87 Text feature [v1804d] present in test data point [True]
# 134 Text feature [highlights] present in test data point [True]
# 138 Text feature [ethnic] present in test data point [True]
# 153 Text feature [threshold] present in test data point [True]
# 167 Text feature [251] present in test data point [True]
# 190 Text feature [fell] present in test data point [True]
# 198 Text feature [penetrance] present in test data point [True]
# 285 Text feature [species] present in test data point [True]
# 309 Text feature [certain] present in test data point [True]
# 326 Text feature [lethal] present in test data point [True]
# 328 Text feature [haplotypes] present in test data point [True]
# 333 Text feature [conferred] present in test data point [True]
# 339 Text feature [ethnicity] present in test data point [True]
# 356 Text feature [brca] present in test data point [True]
# 366 Text feature [fitted] present in test data point [True]
# 368 Text feature [caution] present in test data point [True]
# 375 Text feature [165] present in test data point [True]
# 387 Text feature [phylogenetic] present in test data point [True]
# 389 Text feature [l1764p] present in test data point [True]
# 403 Text feature [values] present in test data point [True]
# 404 Text feature [increasing] present in test data point [True]
# 420 Text feature [women] present in test data point [True]
# 424 Text feature [area] present in test data point [True]
# 432 Text feature [trans] present in test data point [True]
# 440 Text feature [logistic] present in test data point [True]
# 448 Text feature [350] present in test data point [True]
# 451 Text feature [sampling] present in test data point [True]
# 456 Text feature [sizes] present in test data point [True]
# 489 Text feature [123] present in test data point [True]
# Out of the top  500  features  30 are present in query point

# %% [markdown]
# <h4>4.8.1.3.2 Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_bigrams[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_bigrams[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0135 0.0531 0.0046 0.4352 0.0189 0.0058 0.4631 0.0049 0.0009]]
# Actual Class : 4
# --------------------------------------------------
# 26 Text feature [constitutive] present in test data point [True]
# 29 Text feature [cysteine] present in test data point [True]
# 37 Text feature [cdnas] present in test data point [True]
# 45 Text feature [transforming] present in test data point [True]
# 48 Text feature [3t3] present in test data point [True]
# 49 Text feature [constitutively] present in test data point [True]
# 58 Text feature [tyr] present in test data point [True]
# 67 Text feature [upstate] present in test data point [True]
# 70 Text feature [oncogene] present in test data point [True]
# 73 Text feature [downstream] present in test data point [True]
# 94 Text feature [tk] present in test data point [True]
# 96 Text feature [extracellular] present in test data point [True]
# 106 Text feature [enhanced] present in test data point [True]
# 118 Text feature [activated] present in test data point [True]
# 124 Text feature [transformed] present in test data point [True]
# 127 Text feature [expressing] present in test data point [True]
# 134 Text feature [activation] present in test data point [True]
# 146 Text feature [phosphotyrosine] present in test data point [True]
# 156 Text feature [transduction] present in test data point [True]
# 159 Text feature [concentrations] present in test data point [True]
# 165 Text feature [starved] present in test data point [True]
# 184 Text feature [carcinoma] present in test data point [True]
# 226 Text feature [japan] present in test data point [True]
# 268 Text feature [activate] present in test data point [True]
# 282 Text feature [thyroid] present in test data point [True]
# 288 Text feature [factor] present in test data point [True]
# 298 Text feature [long] present in test data point [True]
# 319 Text feature [serum] present in test data point [True]
# 322 Text feature [tyrosine] present in test data point [True]
# 369 Text feature [establish] present in test data point [True]
# 380 Text feature [inserted] present in test data point [True]
# 432 Text feature [threonine] present in test data point [True]
# 434 Text feature [chemiluminescence] present in test data point [True]
# 453 Text feature [clone] present in test data point [True]
# 463 Text feature [untreated] present in test data point [True]
# 491 Text feature [phosphorylation] present in test data point [True]
# Out of the top  500  features  36 are present in query point

# %% [markdown]
# <h3>4.8.2 Without Class balancing</h3>

# %% [markdown]
# <h4>4.8.2.1 Hyper parameter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_bigrams, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_bigrams, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_bigrams)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier( alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_bigrams, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_bigrams, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_bigrams)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_bigrams)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_bigrams)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.2024425563328112
# for alpha = 1e-05
# Log Loss : 1.1956809970808393
# for alpha = 0.0001
# Log Loss : 1.0699611210639894
# for alpha = 0.001
# Log Loss : 1.0661646268572804
# for alpha = 0.01
# Log Loss : 1.1979046743309918
# for alpha = 0.1
# Log Loss : 1.685809679272873
# for alpha = 1
# Log Loss : 1.777858550491557
# for alpha = 10
# Log Loss : 1.7873162633035382
# for alpha = 100
# Log Loss : 1.7882748859330584
# For values of best alpha =  0.001 The train log loss is: 0.6019459694566098
# For values of best alpha =  0.001 The cross validation log loss is: 1.0927513536688918
# For values of best alpha =  0.001 The test log loss is: 0.9787041979398677

# %% [markdown]
# <h4>4.8.2.2 Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_bigrams, train_y, cv_x_onehotCoding_bigrams, cv_y, clf)
# Out:
# Log loss : 1.0661646268572804
# Number of mis-classified points : 0.36654135338345867
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.8.2.3 Correctly classified point</h4>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_bigrams,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_bigrams[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_bigrams[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[2.660e-02 2.400e-03 6.000e-04 5.900e-03 3.860e-02 9.213e-01 7.000e-04
#   3.900e-03 0.000e+00]]
# Actual Class : 6
# --------------------------------------------------
# 19 Text feature [african] present in test data point [True]
# 87 Text feature [v1804d] present in test data point [True]
# 134 Text feature [highlights] present in test data point [True]
# 138 Text feature [ethnic] present in test data point [True]
# 153 Text feature [threshold] present in test data point [True]
# 167 Text feature [251] present in test data point [True]
# 190 Text feature [fell] present in test data point [True]
# 198 Text feature [penetrance] present in test data point [True]
# 285 Text feature [species] present in test data point [True]
# 309 Text feature [certain] present in test data point [True]
# 326 Text feature [lethal] present in test data point [True]
# 328 Text feature [haplotypes] present in test data point [True]
# 333 Text feature [conferred] present in test data point [True]
# 339 Text feature [ethnicity] present in test data point [True]
# 356 Text feature [brca] present in test data point [True]
# 366 Text feature [fitted] present in test data point [True]
# 368 Text feature [caution] present in test data point [True]
# 375 Text feature [165] present in test data point [True]
# 387 Text feature [phylogenetic] present in test data point [True]
# 389 Text feature [l1764p] present in test data point [True]
# 403 Text feature [values] present in test data point [True]
# 404 Text feature [increasing] present in test data point [True]
# 420 Text feature [women] present in test data point [True]
# 424 Text feature [area] present in test data point [True]
# 432 Text feature [trans] present in test data point [True]
# 440 Text feature [logistic] present in test data point [True]
# 448 Text feature [350] present in test data point [True]
# 451 Text feature [sampling] present in test data point [True]
# 456 Text feature [sizes] present in test data point [True]
# 489 Text feature [123] present in test data point [True]
# Out of the top  500  features  30 are present in query point

# %% [markdown]
# <h4>4.8.2.4 Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_bigrams[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_bigrams[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 4
# Predicted Class Probabilities: [[1.120e-02 4.500e-02 4.100e-03 5.218e-01 1.550e-02 5.300e-03 3.915e-01
#   5.100e-03 5.000e-04]]
# Actual Class : 4
# --------------------------------------------------
# 28 Text feature [mc] present in test data point [True]
# 38 Text feature [tgf] present in test data point [True]
# 40 Text feature [beads] present in test data point [True]
# 67 Text feature [nonsense] present in test data point [True]
# 75 Text feature [instability] present in test data point [True]
# 93 Text feature [32p] present in test data point [True]
# 140 Text feature [severely] present in test data point [True]
# 146 Text feature [missense] present in test data point [True]
# 221 Text feature [undetectable] present in test data point [True]
# 240 Text feature [adrenal] present in test data point [True]
# 264 Text feature [hcl] present in test data point [True]
# 270 Text feature [autoradiography] present in test data point [True]
# 287 Text feature [stability] present in test data point [True]
# 301 Text feature [edta] present in test data point [True]
# 322 Text feature [mice] present in test data point [True]
# 325 Text feature [germline] present in test data point [True]
# 380 Text feature [sk] present in test data point [True]
# 444 Text feature [loss] present in test data point [True]
# 447 Text feature [sds] present in test data point [True]
# Out of the top  500  features  19 are present in query point

# %% [markdown]
# ### Feature Engineering

# %%
text_vectorizer = CountVectorizer(min_df=5,ngram_range=(1, 4))
train_text_feature_onehotCoding_4grams = text_vectorizer.fit_transform(train_df['TEXT'])
train_text_features_4grams= text_vectorizer.get_feature_names()
# don't forget to normalize every feature
#train_text_feature_onehotCoding_4grams = normalize(train_text_feature_onehotCoding_4grams, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding_4grams = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
#test_text_feature_onehotCoding_4grams = normalize(test_text_feature_onehotCoding_4grams, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding_4grams = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
#cv_text_feature_onehotCoding_4grams = normalize(cv_text_feature_onehotCoding_4grams, axis=0)

# %%
from sklearn.feature_selection import SelectKBest, chi2
CH2_ =SelectKBest(score_func=chi2,k=5000)
train_text_feature_onehotCoding_4grams_k=CH2_.fit_transform(train_text_feature_onehotCoding_4grams,train_y)
test_text_feature_onehotCoding_4grams_k=CH2_.transform(test_text_feature_onehotCoding_4grams)
cv_text_feature_onehotCoding_4grams_k=CH2_.transform(cv_text_feature_onehotCoding_4grams)

# %%
train_text_feature_onehotCoding_4grams_k = normalize(train_text_feature_onehotCoding_4grams_k, axis=0)
test_text_feature_onehotCoding_4grams_k = normalize(test_text_feature_onehotCoding_4grams_k, axis=0)
cv_text_feature_onehotCoding_4grams_k = normalize(cv_text_feature_onehotCoding_4grams_k, axis=0)

# %%
train_x_onehotCoding_4grams_k = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding_4grams_k)).tocsr()

test_x_onehotCoding_4grams_k = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding_4grams_k)).tocsr()

cv_x_onehotCoding_4grams_k = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding_4grams_k)).tocsr()

# %% [markdown]
# <h4>Hyperparameter tunning of LR </h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_4grams_k, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding_4grams_k, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_4grams_k)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_4grams_k, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding_4grams_k, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_4grams_k)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_4grams_k)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_4grams_k)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.3160176658651779
# for alpha = 1e-05
# Log Loss : 1.1764784900742156
# for alpha = 0.0001
# Log Loss : 0.9937823615141128
# for alpha = 0.001
# Log Loss : 1.0845830474673406
# for alpha = 0.01
# Log Loss : 1.2947777693080504
# for alpha = 0.1
# Log Loss : 1.5412925754860554
# for alpha = 1
# Log Loss : 1.618902267742372
# for alpha = 10
# Log Loss : 1.631804897529149
# for alpha = 100
# Log Loss : 1.6333838504644649
# For values of best alpha =  0.0001 The train log loss is: 0.44406891753934935
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9937823615141128
# For values of best alpha =  0.0001 The test log loss is: 0.9589654432514071

# %% [markdown]
# <h4> Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_4grams_k, train_y, cv_x_onehotCoding_4grams_k, cv_y, clf)
# Out:
# Log loss : 0.9937823615141128
# Number of mis-classified points : 0.3315789473684211
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
from prettytable import PrettyTable

# %%
x = PrettyTable()
x.field_names = ["Model", "train", "cv","test","Misclassified points"]
x.add_row(["Naive Bayes", 0.52, 1.23,1.17,39])
x.add_row(["KNN", 0.64, 1.15,1.04,40])
x.add_row(["Logistic Regression with class balancing", 0.45, 1.10,0.98,38])
x.add_row(["Logistic Regression without class balancing", 0.44, 1.12,1.01,38])
x.add_row(["Linear SVM", 0.55, 1.12,1.06,37])
x.add_row(["Random Forest Classifier with one hot encoding", 0.85, 1.24,1.19,43])
x.add_row(["Random Forest Classifier with response coding", 0.06, 1.42,1.36,53])
x.add_row(["Stack Models:LR + NB + SVM", 0.54, 1.21,1.15,38])
x.add_row(["Maximum Voting Classifier", 0.82, 1.23,1.19,37])
x.add_row(["Logistic Regression with class balancing with CountVectorizer Features\n(unigram and bigram)", 0.59, 1.07,0.95,37])
x.add_row(["Logistic Regression without class balancing with CountVectorizer Features\n(unigram and bigram)", 0.60, 1.09,0.98,37])
x.add_row(["feature engineering(4grams)", 0.44, 0.99,0.96,33])
print(x)
# Out:
# +---------------------------------------------------------------------------+-------+------+------+----------------------+
# |                                   Model                                   | train |  cv  | test | Misclassified points |
# +---------------------------------------------------------------------------+-------+------+------+----------------------+
# |                                Naive Bayes                                |  0.52 | 1.23 | 1.17 |          39          |
# |                                    KNN                                    |  0.64 | 1.15 | 1.04 |          40          |
# |                  Logistic Regression with class balancing                 |  0.45 | 1.1  | 0.98 |          38          |
# |                Logistic Regression without class balancing                |  0.44 | 1.12 | 1.01 |          38          |
# |                                 Linear SVM                                |  0.55 | 1.12 | 1.06 |          37          |
# |               Random Forest Classifier with one hot encoding              |  0.85 | 1.24 | 1.19 |          43          |
# |               Random Forest Classifier with response coding               |  0.06 | 1.42 | 1.36 |          53          |
# |                         Stack Models:LR + NB + SVM                        |  0.54 | 1.21 | 1.15 |          38          |
# |                         Maximum Voting Classifier                         |  0.82 | 1.23 | 1.19 |          37          |
# |   Logistic Regression with class balancing with CountVectorizer Features  |  0.59 | 1.07 | 0.95 |          37          |
# |                            (unigram and bigram)                           |       |      |      |                      |
# | Logistic Regression without class balancing with CountVectorizer Features |  0.6  | 1.09 | 0.98 |          37          |
# |                            (unigram and bigram)                           |       |      |      |                      |
# |                        feature engineering(4grams)                        |  0.44 | 0.99 | 0.96 |          33          |
# +---------------------------------------------------------------------------+-------+------+------+----------------------+

# %% [markdown]
# <h1>Steps</h1>

# %% [markdown]
# * load data and pre process text data
# * perform EDA and univariate analysis
# * trying various model with different features(tfidf,BOW)
# * perform feature engineering to get desired result
# * Compare all models in tabular form.
